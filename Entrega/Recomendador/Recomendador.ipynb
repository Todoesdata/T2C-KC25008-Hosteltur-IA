# %% [markdown]
# # Recomendador
#
# Se han implementado una búsqueda "Híbrida" con tal de realizr la recomendación, con las dos siguientes técnicas:
# - Búsqueda semántica a partir de los Tags (Embeddings + Cosine similarity)
# - Ordenación de las noticias a partir de Categoría y visitas
#
# En los dos casos, se filtra por las noticias de los últimos dos meses de la región/país a la que pertenece el usuario que está leyendo la noticia. Para cada una de las técnicas, se otorga una puntuación, se combinan los dos resultados y se muestran las top 5 noticias con más puntuación. De esta manera, se obtiene la recomendación.

# %%
import pandas as pd

# Important: Make sure your recommender.py file is in the same directory, or in a directory accessible by your Python path.
import funciones_recomendador
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\anaberta\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\anaberta\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
# Load the CSV files as done in your recommender.py script
# Adjust the path if your Data folder is not relative to this notebook
df_noticias_pais = pd.read_csv('../Data/df_noticias_pais.csv')
df_noticias_region = pd.read_csv('../Data/df_noticias_region.csv')

# Convert the 'published' column to datetime, as done in your script
df_noticias_pais['published'] = pd.to_datetime(df_noticias_pais['published'])
df_noticias_region['published'] = pd.to_datetime(df_noticias_region['published'])

# %%
# Call the main function from your recommender.py script
# The main function will handle user input and print the results
recomendacion = funciones_recomendador.main(df_noticias_pais, df_noticias_region)
# Out:
# En caso de querer salir del programa, escribe: exit
#
# Índicame el id de la noticia que estás viendo:  168132
#
# ID de noticia ingresado: 168132
#
# Índicame la fecha en la que estás viendo la noticia en formato AÑO-MES-FECHA:  2025-01-31
#
# La fecha ingresada es: 2025-01-31
#
# ¿De qué país eres?:    Argentina
#
# El país ingresado es: Argentina
#
# Número de noticias: 858
# Número de noticias: 858
# Noticia original:
#        id                                              title  \
# 0  168132  Cerco a las viviendas turísticas: las nuevas n...
#
#                                                 slug          subcategory  \
# 0  168132_cerco-a-las-viviendas-turisticas-las-nu...  Actualidad hotelera
#
#                  category  published  \
# 0  Hoteles y Alojamientos 2025-01-31
#
#                                                 tags       País  \
# 0  alquiler turístico, Ayuntamiento de Granada, A...  Argentina
#
# ...

# %%
# Recomendaciones
## 168132 ; 2025-01-31; Argentina
## 168132 ; 2025-01-31; España ; Galicia
